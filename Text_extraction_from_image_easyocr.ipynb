# %%
import easyocr
import cv2
import matplotlib.pyplot as plt

# %%
reader = easyocr.Reader(['en'], gpu = False)
output = reader.readtext('C:\\Users\\87gou\\Desktop\\Image-text-extraction1\\Image4.jpg')
output
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[117, 167], [663, 167], [663, 209], [117, 209]],
#   '"LESSONS IN LIFE WILL BE',
#   0.9507976791838058),
#  ([[99, 203], [681, 203], [681, 243], [99, 243]],
#   'REPEATED UNTIL THEY ARE',
#   0.8425751818833576),
#  ([[280, 235], [501, 235], [501, 280], [280, 280]],
#   "LEARNED:'",
#   0.9759904718794673),
#  ([[362, 428], [386, 428], [386, 434], [362, 434]],
#   'Aunna',
#   0.0002908819233594821),
#  ([[389, 427], [477, 427], [477, 439], [389, 439]],
#   'scoopnnocp com',
#   0.329601436289033),
#  ([[388.4649861003862, 385.24145691119725],
#    [448.8226116138789, 380.7770137373178],
#    [450.5350138996138, 425.75854308880275],
#    [390.1773883861211, 430.2229862626822]],
#   'R',
#   0.08677002701250913)]

# %%
img = cv2.imread('C:\\Users\\87gou\\Desktop\\Image-text-extraction1\\Image4.jpg')
for detection in result:
    top_left =tuple([int(val) for val in detection[0][0]])
    bottom_right =tuple ([int(val) for val in detection[0][2]])
    img = cv2.rectangle(img,top_left, bottom_right, (0,255,0),5)
plt.figure(figsize=(10,10))
plt.imshow(img)

# %%
for i in output:
    print(i[1])
# Out:
# "LESSONS IN LIFE WILL BE
# REPEATED UNTIL THEY ARE
# LEARNED:'
# Aunna
# scoopnnocp com
# R
